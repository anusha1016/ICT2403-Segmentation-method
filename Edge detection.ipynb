# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
image_path = "01.jpg"  # Change this to your image path
image = cv2.imread(image_path)

# Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply Gaussian Blur to reduce noise
blurred = cv2.GaussianBlur(gray, (5, 5), 0)

# Apply Canny Edge Detection
edges = cv2.Canny(blurred, threshold1=50, threshold2=150)

# Display results
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(gray, cmap='gray')
plt.title("Grayscale Image")

plt.subplot(1,2,2)
plt.imshow(edges, cmap='gray')
plt.title("Canny Edge Detection")

plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
image_path = "01.jpg"  # Change this to your image path
image = cv2.imread(image_path)

# Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Improve contrast using CLAHE (Adaptive Histogram Equalization)
clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
gray = clahe.apply(gray)

# Apply stronger blur to remove noise
blurred = cv2.GaussianBlur(gray, (7, 7), 1)

# Apply Canny Edge Detection with adjusted thresholds
edges = cv2.Canny(blurred, threshold1=30, threshold2=100)

# Display results
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(gray, cmap='gray')
plt.title("Enhanced Grayscale")

plt.subplot(1,2,2)
plt.imshow(edges, cmap='gray')
plt.title("Improved Canny Edge Detection")

plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
image_path = "2.jpg"  # Change this to your image path
image = cv2.imread(image_path)

# Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Improve contrast using CLAHE (Adaptive Histogram Equalization)
clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
gray = clahe.apply(gray)

# Apply stronger blur to remove noise
blurred = cv2.GaussianBlur(gray, (7, 7), 1)

# Apply Canny Edge Detection with adjusted thresholds
edges = cv2.Canny(blurred, threshold1=30, threshold2=100)

# Display results
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(gray, cmap='gray')
plt.title("Enhanced Grayscale")

plt.subplot(1,2,2)
plt.imshow(edges, cmap='gray')
plt.title("Improved Canny Edge Detection")

plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
image_path = "3.jpg"  # Change this to your image path
image = cv2.imread(image_path)

# Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Improve contrast using CLAHE (Adaptive Histogram Equalization)
clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
gray = clahe.apply(gray)

# Apply stronger blur to remove noise
blurred = cv2.GaussianBlur(gray, (7, 7), 1)

# Apply Canny Edge Detection with adjusted thresholds
edges = cv2.Canny(blurred, threshold1=30, threshold2=100)

# Display results
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(gray, cmap='gray')
plt.title("Enhanced Grayscale")

plt.subplot(1,2,2)
plt.imshow(edges, cmap='gray')
plt.title("Improved Canny Edge Detection")

plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
image_path = "4.jpg"  # Change this to your image path
image = cv2.imread(image_path)

# Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Improve contrast using CLAHE (Adaptive Histogram Equalization)
clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
gray = clahe.apply(gray)

# Apply stronger blur to remove noise
blurred = cv2.GaussianBlur(gray, (7, 7), 1)

# Apply Canny Edge Detection with adjusted thresholds
edges = cv2.Canny(blurred, threshold1=30, threshold2=100)

# Display results
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(gray, cmap='gray')
plt.title("Enhanced Grayscale")

plt.subplot(1,2,2)
plt.imshow(edges, cmap='gray')
plt.title("Improved Canny Edge Detection")

plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
image_path = "5.jpg"  # Change this to your image path
image = cv2.imread(image_path)

# Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Improve contrast using CLAHE (Adaptive Histogram Equalization)
clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
gray = clahe.apply(gray)

# Apply stronger blur to remove noise
blurred = cv2.GaussianBlur(gray, (7, 7), 1)

# Apply Canny Edge Detection with adjusted thresholds
edges = cv2.Canny(blurred, threshold1=30, threshold2=100)

# Display results
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(gray, cmap='gray')
plt.title("Enhanced Grayscale")

plt.subplot(1,2,2)
plt.imshow(edges, cmap='gray')
plt.title("Improved Canny Edge Detection")

plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
image_path = "6.jpg"  # Change this to your image path
image = cv2.imread(image_path)

# Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Improve contrast using CLAHE (Adaptive Histogram Equalization)
clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
gray = clahe.apply(gray)

# Apply stronger blur to remove noise
blurred = cv2.GaussianBlur(gray, (7, 7), 1)

# Apply Canny Edge Detection with adjusted thresholds
edges = cv2.Canny(blurred, threshold1=30, threshold2=100)

# Display results
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(gray, cmap='gray')
plt.title("Enhanced Grayscale")

plt.subplot(1,2,2)
plt.imshow(edges, cmap='gray')
plt.title("Improved Canny Edge Detection")

plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
image_path = "7.jpg"  # Change this to your image path
image = cv2.imread(image_path)

# Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Improve contrast using CLAHE (Adaptive Histogram Equalization)
clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
gray = clahe.apply(gray)

# Apply stronger blur to remove noise
blurred = cv2.GaussianBlur(gray, (7, 7), 1)

# Apply Canny Edge Detection with adjusted thresholds
edges = cv2.Canny(blurred, threshold1=30, threshold2=100)

# Display results
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(gray, cmap='gray')
plt.title("Enhanced Grayscale")

plt.subplot(1,2,2)
plt.imshow(edges, cmap='gray')
plt.title("Improved Canny Edge Detection")

plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
image_path = "8.jpg"  # Change this to your image path
image = cv2.imread(image_path)

# Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Improve contrast using CLAHE (Adaptive Histogram Equalization)
clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
gray = clahe.apply(gray)

# Apply stronger blur to remove noise
blurred = cv2.GaussianBlur(gray, (7, 7), 1)

# Apply Canny Edge Detection with adjusted thresholds
edges = cv2.Canny(blurred, threshold1=30, threshold2=100)

# Display results
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(gray, cmap='gray')
plt.title("Enhanced Grayscale")

plt.subplot(1,2,2)
plt.imshow(edges, cmap='gray')
plt.title("Improved Canny Edge Detection")

plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
image_path = "9.jpg"  # Change this to your image path
image = cv2.imread(image_path)

# Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Improve contrast using CLAHE (Adaptive Histogram Equalization)
clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
gray = clahe.apply(gray)

# Apply stronger blur to remove noise
blurred = cv2.GaussianBlur(gray, (7, 7), 1)

# Apply Canny Edge Detection with adjusted thresholds
edges = cv2.Canny(blurred, threshold1=30, threshold2=100)

# Display results
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(gray, cmap='gray')
plt.title("Enhanced Grayscale")

plt.subplot(1,2,2)
plt.imshow(edges, cmap='gray')
plt.title("Improved Canny Edge Detection")

plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
image_path = "10.jpg"  # Change this to your image path
image = cv2.imread(image_path)

# Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Improve contrast using CLAHE (Adaptive Histogram Equalization)
clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
gray = clahe.apply(gray)

# Apply stronger blur to remove noise
blurred = cv2.GaussianBlur(gray, (7, 7), 1)

# Apply Canny Edge Detection with adjusted thresholds
edges = cv2.Canny(blurred, threshold1=30, threshold2=100)

# Display results
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(gray, cmap='gray')
plt.title("Enhanced Grayscale")

plt.subplot(1,2,2)
plt.imshow(edges, cmap='gray')
plt.title("Improved Canny Edge Detection")

plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
image_path = "11.jpg"  # Change this to your image path
image = cv2.imread(image_path)

# Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Improve contrast using CLAHE (Adaptive Histogram Equalization)
clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
gray = clahe.apply(gray)

# Apply stronger blur to remove noise
blurred = cv2.GaussianBlur(gray, (7, 7), 1)

# Apply Canny Edge Detection with adjusted thresholds
edges = cv2.Canny(blurred, threshold1=30, threshold2=100)

# Display results
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(gray, cmap='gray')
plt.title("Enhanced Grayscale")

plt.subplot(1,2,2)
plt.imshow(edges, cmap='gray')
plt.title("Improved Canny Edge Detection")

plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
image_path = "12.jpg"  # Change this to your image path
image = cv2.imread(image_path)

# Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Improve contrast using CLAHE (Adaptive Histogram Equalization)
clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
gray = clahe.apply(gray)

# Apply stronger blur to remove noise
blurred = cv2.GaussianBlur(gray, (7, 7), 1)

# Apply Canny Edge Detection with adjusted thresholds
edges = cv2.Canny(blurred, threshold1=30, threshold2=100)

# Display results
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(gray, cmap='gray')
plt.title("Enhanced Grayscale")

plt.subplot(1,2,2)
plt.imshow(edges, cmap='gray')
plt.title("Improved Canny Edge Detection")

plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
image_path = "13.jpg"  # Change this to your image path
image = cv2.imread(image_path)

# Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Improve contrast using CLAHE (Adaptive Histogram Equalization)
clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
gray = clahe.apply(gray)

# Apply stronger blur to remove noise
blurred = cv2.GaussianBlur(gray, (7, 7), 1)

# Apply Canny Edge Detection with adjusted thresholds
edges = cv2.Canny(blurred, threshold1=30, threshold2=100)

# Display results
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(gray, cmap='gray')
plt.title("Enhanced Grayscale")

plt.subplot(1,2,2)
plt.imshow(edges, cmap='gray')
plt.title("Improved Canny Edge Detection")

plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
image_path = "14.jpg"  # Change this to your image path
image = cv2.imread(image_path)

# Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Improve contrast using CLAHE (Adaptive Histogram Equalization)
clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
gray = clahe.apply(gray)

# Apply stronger blur to remove noise
blurred = cv2.GaussianBlur(gray, (7, 7), 1)

# Apply Canny Edge Detection with adjusted thresholds
edges = cv2.Canny(blurred, threshold1=30, threshold2=100)

# Display results
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(gray, cmap='gray')
plt.title("Enhanced Grayscale")

plt.subplot(1,2,2)
plt.imshow(edges, cmap='gray')
plt.title("Improved Canny Edge Detection")

plt.show()
