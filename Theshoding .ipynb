# %%
import cv2
import numpy as np

# Load image
image = cv2.imread('01.jpg')
if image is None: 
    print("Error: Unable to load the images") 
else: 
    print ("Successfully loaded ") 
gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

(thresh, binary) = cv2.threshold(gray_image, 127, 255,cv2.THRESH_OTSU) 
cv2.imshow('image',image)
cv2.imshow("Gray Image",gray_image)
cv2.imshow("Black and White Image",binary)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Successfully loaded

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
image_path = "01.jpg" 
image = cv2.imread(image_path)

# Convert to HSV color space
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

lower_green = np.array([30, 40, 40])   
upper_green = np.array([90, 255, 255]) 
mask = cv2.inRange(hsv, lower_green, upper_green)

# Apply morphological operations
kernel = np.ones((3,3), np.uint8)
mask_cleaned = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel, iterations=2)
plant_isolated = cv2.bitwise_and(image, image, mask=mask_cleaned)

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(mask_cleaned, cmap='gray')
plt.title("Green Color Mask")

plt.subplot(1,2,2)
plt.imshow(cv2.cvtColor(plant_isolated, cv2.COLOR_BGR2RGB))
plt.title("Isolated Plant")
plt.show()

# %%
import cv2
import numpy as np
0
# Load image
image = cv2.imread('2.jpg')
if image is None: 
    print("Error: Unable to load the images") 
else: 
    print ("Successfully loaded ") 
gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

(thresh, binary) = cv2.threshold(gray_image, 127, 255,cv2.THRESH_OTSU) 
cv2.imshow('image',image)
cv2.imshow("Gray Image",gray_image)
cv2.imshow("Black and White Image",binary)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Successfully loaded

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
image_path = "2.jpg" 
image = cv2.imread(image_path)

# Convert to HSV color space
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

lower_green = np.array([30, 40, 40])   
upper_green = np.array([90, 255, 255]) 
mask = cv2.inRange(hsv, lower_green, upper_green)

# Apply morphological operations
kernel = np.ones((3,3), np.uint8)
mask_cleaned = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel, iterations=2)
plant_isolated = cv2.bitwise_and(image, image, mask=mask_cleaned)

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(mask_cleaned, cmap='gray')
plt.title("Green Color Mask")

plt.subplot(1,2,2)
plt.imshow(cv2.cvtColor(plant_isolated, cv2.COLOR_BGR2RGB))
plt.title("Isolated Plant")
plt.show()

# %%
import cv2
import numpy as np

# Load image
image = cv2.imread('3.jpg')
if image is None: 
    print("Error: Unable to load the images") 
else: 
    print ("Successfully loaded ") 
gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

(thresh, binary) = cv2.threshold(gray_image, 127, 255,cv2.THRESH_OTSU) 
cv2.imshow('image',image)
cv2.imshow("Gray Image",gray_image)
cv2.imshow("Black and White Image",binary)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Successfully loaded

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
image_path = "3.jpg" 
image = cv2.imread(image_path)

# Convert to HSV color space
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

lower_green = np.array([30, 40, 40])   
upper_green = np.array([90, 255, 255]) 
mask = cv2.inRange(hsv, lower_green, upper_green)

# Apply morphological operations
kernel = np.ones((3,3), np.uint8)
mask_cleaned = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel, iterations=2)
plant_isolated = cv2.bitwise_and(image, image, mask=mask_cleaned)

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(mask_cleaned, cmap='gray')
plt.title("Green Color Mask")

plt.subplot(1,2,2)
plt.imshow(cv2.cvtColor(plant_isolated, cv2.COLOR_BGR2RGB))
plt.title("Isolated Plant")
plt.show()

# %%
import cv2
import numpy as np

# Load image
image = cv2.imread('4.jpg')
if image is None: 
    print("Error: Unable to load the images") 
else: 
    print ("Successfully loaded ") 
gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

(thresh, binary) = cv2.threshold(gray_image, 127, 255,cv2.THRESH_OTSU) 
cv2.imshow('image',image)
cv2.imshow("Gray Image",gray_image)
cv2.imshow("Black and White Image",binary)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Successfully loaded

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
image_path = "4.jpg" 
image = cv2.imread(image_path)

# Convert to HSV color space
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

lower_green = np.array([30, 40, 40])   
upper_green = np.array([90, 255, 255]) 
mask = cv2.inRange(hsv, lower_green, upper_green)

# Apply morphological operations
kernel = np.ones((3,3), np.uint8)
mask_cleaned = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel, iterations=2)
plant_isolated = cv2.bitwise_and(image, image, mask=mask_cleaned)

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(mask_cleaned, cmap='gray')
plt.title("Green Color Mask")

plt.subplot(1,2,2)
plt.imshow(cv2.cvtColor(plant_isolated, cv2.COLOR_BGR2RGB))
plt.title("Isolated Plant")
plt.show()

# %%
import cv2
import numpy as np

# Load image
image = cv2.imread('5.jpg')
if image is None: 
    print("Error: Unable to load the images") 
else: 
    print ("Successfully loaded ") 
gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

(thresh, binary) = cv2.threshold(gray_image, 127, 255,cv2.THRESH_OTSU) 
cv2.imshow('image',image)
cv2.imshow("Gray Image",gray_image)
cv2.imshow("Black and White Image",binary)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Successfully loaded

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
image_path = "5.jpg" 
image = cv2.imread(image_path)

# Convert to HSV color space
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

lower_green = np.array([30, 40, 40])   
upper_green = np.array([90, 255, 255]) 
mask = cv2.inRange(hsv, lower_green, upper_green)

# Apply morphological operations
kernel = np.ones((3,3), np.uint8)
mask_cleaned = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel, iterations=2)
plant_isolated = cv2.bitwise_and(image, image, mask=mask_cleaned)

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(mask_cleaned, cmap='gray')
plt.title("Green Color Mask")

plt.subplot(1,2,2)
plt.imshow(cv2.cvtColor(plant_isolated, cv2.COLOR_BGR2RGB))
plt.title("Isolated Plant")
plt.show()

# %%
import cv2
import numpy as np

# Load image
image = cv2.imread('6.jpg')
if image is None: 
    print("Error: Unable to load the images") 
else: 
    print ("Successfully loaded ") 
gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

(thresh, binary) = cv2.threshold(gray_image, 127, 255,cv2.THRESH_OTSU) 
cv2.imshow('image',image)
cv2.imshow("Gray Image",gray_image)
cv2.imshow("Black and White Image",binary)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Successfully loaded

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
image_path = "6.jpg" 
image = cv2.imread(image_path)

# Convert to HSV color space
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

lower_green = np.array([30, 40, 40])   
upper_green = np.array([90, 255, 255]) 
mask = cv2.inRange(hsv, lower_green, upper_green)

# Apply morphological operations
kernel = np.ones((3,3), np.uint8)
mask_cleaned = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel, iterations=2)
plant_isolated = cv2.bitwise_and(image, image, mask=mask_cleaned)

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(mask_cleaned, cmap='gray')
plt.title("Green Color Mask")

plt.subplot(1,2,2)
plt.imshow(cv2.cvtColor(plant_isolated, cv2.COLOR_BGR2RGB))
plt.title("Isolated Plant")
plt.show()

# %%
import cv2
import numpy as np

# Load image
image = cv2.imread('7.jpg')
if image is None: 
    print("Error: Unable to load the images") 
else: 
    print ("Successfully loaded ") 
gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

(thresh, binary) = cv2.threshold(gray_image, 127, 255,cv2.THRESH_OTSU) 
cv2.imshow('image',image)
cv2.imshow("Gray Image",gray_image)
cv2.imshow("Black and White Image",binary)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Successfully loaded

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
image_path = "7.jpg" 
image = cv2.imread(image_path)

# Convert to HSV color space
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

lower_green = np.array([30, 40, 40])   
upper_green = np.array([90, 255, 255]) 
mask = cv2.inRange(hsv, lower_green, upper_green)

# Apply morphological operations
kernel = np.ones((3,3), np.uint8)
mask_cleaned = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel, iterations=2)
plant_isolated = cv2.bitwise_and(image, image, mask=mask_cleaned)

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(mask_cleaned, cmap='gray')
plt.title("Green Color Mask")

plt.subplot(1,2,2)
plt.imshow(cv2.cvtColor(plant_isolated, cv2.COLOR_BGR2RGB))
plt.title("Isolated Plant")
plt.show()

# %%
import cv2
import numpy as np

# Load image
image = cv2.imread('8.jpg')
if image is None: 
    print("Error: Unable to load the images") 
else: 
    print ("Successfully loaded ") 
gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

(thresh, binary) = cv2.threshold(gray_image, 127, 255,cv2.THRESH_OTSU) 
cv2.imshow('image',image)
cv2.imshow("Gray Image",gray_image)
cv2.imshow("Black and White Image",binary)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Successfully loaded

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
image_path = "8.jpg" 
image = cv2.imread(image_path)

# Convert to HSV color space
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

lower_green = np.array([30, 40, 40])   
upper_green = np.array([90, 255, 255]) 
mask = cv2.inRange(hsv, lower_green, upper_green)

# Apply morphological operations
kernel = np.ones((3,3), np.uint8)
mask_cleaned = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel, iterations=2)
plant_isolated = cv2.bitwise_and(image, image, mask=mask_cleaned)

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(mask_cleaned, cmap='gray')
plt.title("Green Color Mask")

plt.subplot(1,2,2)
plt.imshow(cv2.cvtColor(plant_isolated, cv2.COLOR_BGR2RGB))
plt.title("Isolated Plant")
plt.show()

# %%
import cv2
import numpy as np

# Load image
image = cv2.imread('9.jpg')
if image is None: 
    print("Error: Unable to load the images") 
else: 
    print ("Successfully loaded ") 
gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

(thresh, binary) = cv2.threshold(gray_image, 127, 255,cv2.THRESH_OTSU) 
cv2.imshow('image',image)
cv2.imshow("Gray Image",gray_image)
cv2.imshow("Black and White Image",binary)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Successfully loaded

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
image_path = "9.jpg" 
image = cv2.imread(image_path)

# Convert to HSV color space
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

lower_green = np.array([30, 40, 40])   
upper_green = np.array([90, 255, 255]) 
mask = cv2.inRange(hsv, lower_green, upper_green)

# Apply morphological operations
kernel = np.ones((3,3), np.uint8)
mask_cleaned = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel, iterations=2)
plant_isolated = cv2.bitwise_and(image, image, mask=mask_cleaned)

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(mask_cleaned, cmap='gray')
plt.title("Green Color Mask")

plt.subplot(1,2,2)
plt.imshow(cv2.cvtColor(plant_isolated, cv2.COLOR_BGR2RGB))
plt.title("Isolated Plant")
plt.show()

# %%
import cv2
import numpy as np

# Load image
image = cv2.imread('10.jpg')
if image is None: 
    print("Error: Unable to load the images") 
else: 
    print ("Successfully loaded ") 
gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

(thresh, binary) = cv2.threshold(gray_image, 127, 255,cv2.THRESH_OTSU) 
cv2.imshow('image',image)
cv2.imshow("Gray Image",gray_image)
cv2.imshow("Black and White Image",binary)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Successfully loaded

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
image_path = "10.jpg" 
image = cv2.imread(image_path)

# Convert to HSV color space
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

lower_green = np.array([30, 40, 40])   
upper_green = np.array([90, 255, 255]) 
mask = cv2.inRange(hsv, lower_green, upper_green)

# Apply morphological operations
kernel = np.ones((3,3), np.uint8)
mask_cleaned = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel, iterations=2)
plant_isolated = cv2.bitwise_and(image, image, mask=mask_cleaned)

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(mask_cleaned, cmap='gray')
plt.title("Green Color Mask")

plt.subplot(1,2,2)
plt.imshow(cv2.cvtColor(plant_isolated, cv2.COLOR_BGR2RGB))
plt.title("Isolated Plant")
plt.show()

# %%
import cv2
import numpy as np

# Load image
image = cv2.imread('11.jpg')
if image is None: 
    print("Error: Unable to load the images") 
else: 
    print ("Successfully loaded ") 
gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

(thresh, binary) = cv2.threshold(gray_image, 127, 255,cv2.THRESH_OTSU) 
cv2.imshow('image',image)
cv2.imshow("Gray Image",gray_image)
cv2.imshow("Black and White Image",binary)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Successfully loaded

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
image_path = "11.jpg" 
image = cv2.imread(image_path)

# Convert to HSV color space
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

lower_green = np.array([30, 40, 40])   
upper_green = np.array([90, 255, 255]) 
mask = cv2.inRange(hsv, lower_green, upper_green)

# Apply morphological operations
kernel = np.ones((3,3), np.uint8)
mask_cleaned = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel, iterations=2)
plant_isolated = cv2.bitwise_and(image, image, mask=mask_cleaned)

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(mask_cleaned, cmap='gray')
plt.title("Green Color Mask")

plt.subplot(1,2,2)
plt.imshow(cv2.cvtColor(plant_isolated, cv2.COLOR_BGR2RGB))
plt.title("Isolated Plant")
plt.show()

# %%
import cv2
import numpy as np

# Load image
image = cv2.imread('12.jpg')
if image is None: 
    print("Error: Unable to load the images") 
else: 
    print ("Successfully loaded ") 
gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

(thresh, binary) = cv2.threshold(gray_image, 127, 255,cv2.THRESH_OTSU) 
cv2.imshow('image',image)
cv2.imshow("Gray Image",gray_image)
cv2.imshow("Black and White Image",binary)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Successfully loaded

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
image_path = "12.jpg" 
image = cv2.imread(image_path)

# Convert to HSV color space
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

lower_green = np.array([30, 40, 40])   
upper_green = np.array([90, 255, 255]) 
mask = cv2.inRange(hsv, lower_green, upper_green)

# Apply morphological operations
kernel = np.ones((3,3), np.uint8)
mask_cleaned = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel, iterations=2)
plant_isolated = cv2.bitwise_and(image, image, mask=mask_cleaned)

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(mask_cleaned, cmap='gray')
plt.title("Green Color Mask")

plt.subplot(1,2,2)
plt.imshow(cv2.cvtColor(plant_isolated, cv2.COLOR_BGR2RGB))
plt.title("Isolated Plant")
plt.show()

# %%
import cv2
import numpy as np

# Load image
image = cv2.imread('13.jpg')
if image is None: 
    print("Error: Unable to load the images") 
else: 
    print ("Successfully loaded ") 
gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

(thresh, binary) = cv2.threshold(gray_image, 127, 255,cv2.THRESH_OTSU) 
cv2.imshow('image',image)
cv2.imshow("Gray Image",gray_image)
cv2.imshow("Black and White Image",binary)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Successfully loaded

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
image_path = "13.jpg" 
image = cv2.imread(image_path)

# Convert to HSV color space
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

lower_green = np.array([30, 40, 40])   
upper_green = np.array([90, 255, 255]) 
mask = cv2.inRange(hsv, lower_green, upper_green)

# Apply morphological operations
kernel = np.ones((3,3), np.uint8)
mask_cleaned = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel, iterations=2)
plant_isolated = cv2.bitwise_and(image, image, mask=mask_cleaned)

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(mask_cleaned, cmap='gray')
plt.title("Green Color Mask")

plt.subplot(1,2,2)
plt.imshow(cv2.cvtColor(plant_isolated, cv2.COLOR_BGR2RGB))
plt.title("Isolated Plant")
plt.show()

# %%
import cv2
import numpy as np

# Load image
image = cv2.imread('14.jpg')
if image is None: 
    print("Error: Unable to load the images") 
else: 
    print ("Successfully loaded ") 
gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

(thresh, binary) = cv2.threshold(gray_image, 127, 255,cv2.THRESH_OTSU) 
cv2.imshow('image',image)
cv2.imshow("Gray Image",gray_image)
cv2.imshow("Black and White Image",binary)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Successfully loaded

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
image_path = "14.jpg" 
image = cv2.imread(image_path)

# Convert to HSV color space
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

lower_green = np.array([30, 40, 40])   
upper_green = np.array([90, 255, 255]) 
mask = cv2.inRange(hsv, lower_green, upper_green)

# Apply morphological operations
kernel = np.ones((3,3), np.uint8)
mask_cleaned = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel, iterations=2)
plant_isolated = cv2.bitwise_and(image, image, mask=mask_cleaned)

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(mask_cleaned, cmap='gray')
plt.title("Green Color Mask")

plt.subplot(1,2,2)
plt.imshow(cv2.cvtColor(plant_isolated, cv2.COLOR_BGR2RGB))
plt.title("Isolated Plant")
plt.show()
